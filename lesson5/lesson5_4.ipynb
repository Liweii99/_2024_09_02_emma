# %%
import random #0914
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)

# %%
import requests
r=requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"42077389827","type":"PushEvent","actor":{"id":166895733,"login":"swa-runner-app[bot]","display_login":"swa-runner-app","gravatar_id":"","url":"https://api.github.com/users/swa-runner-app[bot]","avatar_url":"https://avatars.githubusercontent.com/u/166895733?"},"repo":{"id":859844320,"name":"static-web-apps-testing-org/swa7a46017377c04711894b594da67c14ce","url":"https://api.github.com/repos/static-web-apps-testing-org/swa7a46017377c04711894b594da67c14ce"},"payload":{"repository_id":859844320,"push_id":20313404654,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"61553e5b4cc49764aba4599e642cf222d05113a9","before":"8f020623fcdf3e5a8e368efd19085c5f1152cff8","commits":[{"sha":"61553e5b4cc49764aba4599e642cf222d05113a9","author":{"email":"166895733+swa-runner-app[bot]@users.noreply.github.com","name":"swa-runner-app[bot]"},"message":"Writing file src/favicon.ico","distinct":true,"url":"https://api.github.com/repos/static-web-apps-testing-org/swa7a46017377c04711894b594da67c1
# ...
